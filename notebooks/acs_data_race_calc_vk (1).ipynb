# %%
import pandas as pd

# %%
acs_df = pd.read_csv('acs_5yr_2016.csv')
# Out:
# /Users/victoriakielb/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3319: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
acs_df.head()
# Out:
#    Unnamed: 0                                census_name  \
# 0           0     Census Tract 113, Dallas County, Texas
# 1           1  Census Tract 122.09, Dallas County, Texas
# 2           2     Census Tract 128, Dallas County, Texas
# 3           3  Census Tract 137.25, Dallas County, Texas
# 4           4  Census Tract 138.04, Dallas County, Texas
#
#    Estimate!!Total: TOTAL POPULATION  Estimate!!Total: SEX BY AGE  \
# 0                             4985.0                       4985.0
# 1                             3459.0                       3459.0
# 2                             7520.0                       7520.0
# 3                             4405.0                       4405.0
# 4                             3428.0                       3428.0
#
#    Estimate!!Total:!!Male: SEX BY AGE  \
# 0                              2031.0
# 1                              1728.0
# 2                              3835.0
# 3                              2051.0
# ...

# %%
acs_df_race = acs_df[["Estimate!!Total:!!Not Hispanic or Latino: HISPANIC OR LATINO ORIGIN BY RACE", 
                      "Estimate!!Total:!!Not Hispanic or Latino:!!White alone HISPANIC OR LATINO ORIGIN BY RACE",
                      "Estimate!!Total:!!Not Hispanic or Latino:!!Black or African American alone HISPANIC OR LATINO ORIGIN BY RACE",
                      "Estimate!!Total:!!Not Hispanic or Latino:!!American Indian and Alaska Native alone HISPANIC OR LATINO ORIGIN BY RACE",
                      "Estimate!!Total:!!Not Hispanic or Latino:!!Asian alone HISPANIC OR LATINO ORIGIN BY RACE",
                      "Estimate!!Total:!!Not Hispanic or Latino:!!Native Hawaiian and Other Pacific Islander alone HISPANIC OR LATINO ORIGIN BY RACE",
                      "Estimate!!Total:!!Not Hispanic or Latino:!!Some other race alone HISPANIC OR LATINO ORIGIN BY RACE",
                      "Estimate!!Total:!!Not Hispanic or Latino:!!Two or more races: HISPANIC OR LATINO ORIGIN BY RACE",
                      "Estimate!!Total:!!Not Hispanic or Latino:!!Two or more races:!!Two races including Some other race HISPANIC OR LATINO ORIGIN BY RACE",
                      "Estimate!!Total:!!Not Hispanic or Latino:!!Two or more races:!!Two races excluding Some other race, and three or more races HISPANIC OR LATINO ORIGIN BY RACE",
                      "Estimate!!Total:!!Hispanic or Latino: HISPANIC OR LATINO ORIGIN BY RACE",
                      "Estimate!!Total:!!Hispanic or Latino:!!White alone HISPANIC OR LATINO ORIGIN BY RACE",
                      "Estimate!!Total:!!Hispanic or Latino:!!Black or African American alone HISPANIC OR LATINO ORIGIN BY RACE",
                      "Estimate!!Total:!!Hispanic or Latino:!!American Indian and Alaska Native alone HISPANIC OR LATINO ORIGIN BY RACE",
                      "Estimate!!Total:!!Hispanic or Latino:!!Asian alone HISPANIC OR LATINO ORIGIN BY RACE",
                      "Estimate!!Total:!!Hispanic or Latino:!!Native Hawaiian and Other Pacific Islander alone HISPANIC OR LATINO ORIGIN BY RACE",
                      "Estimate!!Total:!!Hispanic or Latino:!!Some other race alone HISPANIC OR LATINO ORIGIN BY RACE",
                      "Estimate!!Total:!!Hispanic or Latino:!!Two or more races: HISPANIC OR LATINO ORIGIN BY RACE",
                      "Estimate!!Total:!!Hispanic or Latino:!!Two or more races:!!Two races including Some other race HISPANIC OR LATINO ORIGIN BY RACE",
                      "Estimate!!Total:!!Hispanic or Latino:!!Two or more races:!!Two races excluding Some other race, and three or more races HISPANIC OR LATINO ORIGIN BY RACE"
                      ]]

# %%
acs_df_race_clean = acs_df_race.rename(columns={"Estimate!!Total:!!Not Hispanic or Latino: HISPANIC OR LATINO ORIGIN BY RACE": "Not H/L",
                      "Estimate!!Total:!!Not Hispanic or Latino:!!White alone HISPANIC OR LATINO ORIGIN BY RACE": "Not H/L: White alone",
                      "Estimate!!Total:!!Not Hispanic or Latino:!!Black or African American alone HISPANIC OR LATINO ORIGIN BY RACE":"Not H/L: Black alone",
                      "Estimate!!Total:!!Not Hispanic or Latino:!!American Indian and Alaska Native alone HISPANIC OR LATINO ORIGIN BY RACE":"Not H/L: American Indian/Native alone",
                      "Estimate!!Total:!!Not Hispanic or Latino:!!Asian alone HISPANIC OR LATINO ORIGIN BY RACE": "Not H/L: Asian alone",
                      "Estimate!!Total:!!Not Hispanic or Latino:!!Native Hawaiian and Other Pacific Islander alone HISPANIC OR LATINO ORIGIN BY RACE" : "Not H/L: Native Hawaiian / PI alone",
                      "Estimate!!Total:!!Not Hispanic or Latino:!!Some other race alone HISPANIC OR LATINO ORIGIN BY RACE":"Not H/L: Other race alone",
                      "Estimate!!Total:!!Not Hispanic or Latino:!!Two or more races: HISPANIC OR LATINO ORIGIN BY RACE":"Not H/L: Two or more races",
                      "Estimate!!Total:!!Not Hispanic or Latino:!!Two or more races:!!Two races including Some other race HISPANIC OR LATINO ORIGIN BY RACE": "Not H/L: Two races including other race",
                      "Estimate!!Total:!!Not Hispanic or Latino:!!Two or more races:!!Two races excluding Some other race, and three or more races HISPANIC OR LATINO ORIGIN BY RACE": "Not H/L: Two races excluding other race, and three+ races",
                      "Estimate!!Total:!!Hispanic or Latino: HISPANIC OR LATINO ORIGIN BY RACE": "H/L",
                      "Estimate!!Total:!!Hispanic or Latino:!!White alone HISPANIC OR LATINO ORIGIN BY RACE":"H/L: White alone",
                      "Estimate!!Total:!!Hispanic or Latino:!!Black or African American alone HISPANIC OR LATINO ORIGIN BY RACE":"H/L: Black alone",
                      "Estimate!!Total:!!Hispanic or Latino:!!American Indian and Alaska Native alone HISPANIC OR LATINO ORIGIN BY RACE":"H/L: American Indian/Native alone",
                      "Estimate!!Total:!!Hispanic or Latino:!!Asian alone HISPANIC OR LATINO ORIGIN BY RACE":"H/L: Asian alone",
                      "Estimate!!Total:!!Hispanic or Latino:!!Native Hawaiian and Other Pacific Islander alone HISPANIC OR LATINO ORIGIN BY RACE":"H/L: Native Hawaiian / PI alone",
                      "Estimate!!Total:!!Hispanic or Latino:!!Some other race alone HISPANIC OR LATINO ORIGIN BY RACE":"H/L: Other race alone",
                      "Estimate!!Total:!!Hispanic or Latino:!!Two or more races: HISPANIC OR LATINO ORIGIN BY RACE":"H/L: Two or more races",
                      "Estimate!!Total:!!Hispanic or Latino:!!Two or more races:!!Two races including Some other race HISPANIC OR LATINO ORIGIN BY RACE":"H/L: Two races including other race",
                      "Estimate!!Total:!!Hispanic or Latino:!!Two or more races:!!Two races excluding Some other race, and three or more races HISPANIC OR LATINO ORIGIN BY RACE":"H/L: Two races excluding other race, and three+ races"
                      })

# %%
acs_df_race_clean.sum(axis = 0, skipna = True)
# Out:
# Not H/L                                                      101486164.0
# Not H/L: White alone                                          74946852.0
# Not H/L: Black alone                                          12700476.0
# Not H/L: American Indian/Native alone                           712320.0
# Not H/L: Asian alone                                           9408053.0
# Not H/L: Native Hawaiian / PI alone                             247582.0
# Not H/L: Other race alone                                       265219.0
# Not H/L: Two or more races                                     3205662.0
# Not H/L: Two races including other race                         134470.0
# Not H/L: Two races excluding other race, and three+ races      3071192.0
# H/L                                                           34391667.0
# H/L: White alone                                              23019691.0
# H/L: Black alone                                                366236.0
# ...

# %% [markdown]
# ### Creating "cleaned" race columns
#
# Cleaned columns will include:
#
# *  Hispanic (of any race)
# *  Non-Hispanic White
# *  Non-Hispanic Black
# *  Non-Hispanic Asian
# *  Non-Hispanic American Indian
# *  Non-Hispanic Other

# %%
acs_df_race_clean['Hispanic (of any race)'] = acs_df_race_clean['H/L']
acs_df_race_clean['Non-Hispanic White'] = acs_df_race_clean['Not H/L: White alone']
acs_df_race_clean['Non-Hispanic Black'] = acs_df_race_clean['Not H/L: Black alone']
acs_df_race_clean['Non-Hispanic Asian'] = acs_df_race_clean['Not H/L: Asian alone']
acs_df_race_clean['Non-Hispanic American Indian'] = acs_df_race_clean['Not H/L: American Indian/Native alone']

# %%
acs_df_race_clean['Non-Hispanic Other'] = acs_df_race_clean['Not H/L: Native Hawaiian / PI alone'] + acs_df_race_clean['Not H/L: Other race alone'] + acs_df_race_clean['Not H/L: Two or more races']

# %%
acs_df_race_final = acs_df_race_clean[['Hispanic (of any race)',
                                       'Non-Hispanic White',
                                       'Non-Hispanic Black',
                                       'Non-Hispanic Asian',
                                       'Non-Hispanic American Indian',
                                       'Non-Hispanic Other'
                                      ]]

# %%
acs_df_race_final.head()
# Out:
#    Hispanic (of any race)  Non-Hispanic White  Non-Hispanic Black  \
# 0                     NaN                 NaN                 NaN
# 1                     NaN                 NaN                 NaN
# 2                     NaN                 NaN                 NaN
# 3                     NaN                 NaN                 NaN
# 4                     NaN                 NaN                 NaN
#
#    Non-Hispanic Asian  Non-Hispanic American Indian  Non-Hispanic Other
# 0                 NaN                           NaN                 NaN
# 1                 NaN                           NaN                 NaN
# 2                 NaN                           NaN                 NaN
# 3                 NaN                           NaN                 NaN
# 4                 NaN                           NaN                 NaN

# %%
acs_df_race_final.sum(axis = 0, skipna = True)
# Out:
# Hispanic (of any race)          34391667.0
# Non-Hispanic White              74946852.0
# Non-Hispanic Black              12700476.0
# Non-Hispanic Asian               9408053.0
# Non-Hispanic American Indian      712320.0
# Non-Hispanic Other               3718463.0
# dtype: float64
