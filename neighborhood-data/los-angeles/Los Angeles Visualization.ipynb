# %%
# !pip install geopandas
# !pip install contextily

import geopandas
import contextily as cx

# %%
la = geopandas.read_file('Los Angeles')

# %%
la = la.to_crs(epsg=3857)

ax = la.plot(figsize=(20, 20), alpha=0.5, edgecolor='k')
cx.add_basemap(ax)
