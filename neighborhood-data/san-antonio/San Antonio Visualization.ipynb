# %%
import geopandas
import contextily as cx

# %%
satx = geopandas.read_file("/Users/bruno/broadbandequity/broadbandequity/neighborhood-data/san-antonio/san-antonio/San Antonio.geojson")

# %%
satx = satx.to_crs(epsg=3857)

ax = satx.plot(figsize=(20, 20), alpha=0.5, edgecolor='k')
cx.add_basemap(ax)
