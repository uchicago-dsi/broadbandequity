# %%
import geopandas
import contextily as cx

# %%
htx = geopandas.read_file('Houston')

# %%
htx = htx.to_crs(epsg=3857)

ax = htx.plot(figsize=(20, 20), alpha=0.5, edgecolor='k')
cx.add_basemap(ax)
