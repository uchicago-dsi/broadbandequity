# %%
import geopandas
import contextily as cx

# %%
philly = geopandas.read_file('Philadelphia')

# %%
philly = philly.to_crs(epsg=3857)

ax = philly.plot(figsize=(20, 20), alpha=0.5, edgecolor='k')
cx.add_basemap(ax)
