# %%
import geopandas
import contextily as cx

# %%
pho = geopandas.read_file('Phoenix')

# %%
pho = pho.to_crs(epsg=3857)

ax = pho.plot(figsize=(20, 20), alpha=0.5, edgecolor='k')
cx.add_basemap(ax)
