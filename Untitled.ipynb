# %%
pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 1.0 MB 1.7 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 2.8 MB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/homebrew/Cellar/jupyterlab/3.2.8/libexec/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/yh/k_65n3ts3434_qy657hn5pmw0000gn/T/pip-install-b0i0nzbd/fiona_89efe255d0b344909e3baa3ae02e46ae/setup.py'"'"'; __file__='"'"'/private/var/folders/yh/k_65n3ts3434_qy657hn5pmw0000gn/T/pip-install-b0i0nzbd/fiona_89efe255d0b344909e3baa3ae02e46ae/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/yh/k_65n3ts3434_qy657hn5pmw0000gn/T/pip-pip-egg-info-eggs_ney
# ...

# %%
pip install tobler
# Out:
# ...
#      |████████████████████████████████| 2.3 MB 5.9 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/homebrew/Cellar/jupyterlab/3.2.8/libexec/bin/python3.9 /opt/homebrew/Cellar/jupyterlab/3.2.8/libexec/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /var/folders/yh/k_65n3ts3434_qy657hn5pmw0000gn/T/tmp7ycula9n
#        cwd: /private/var/folders/yh/k_65n3ts3434_qy657hn5pmw0000gn/T/pip-install-mlll17i2/rasterio_0c47b62baf024e95a955703fe17ba914
#   Complete output (2 lines):
#   WARNING:root:Failed to get options via gdal-config: [Errno 2] No such file or directory: 'gdal-config'
#   ERROR: A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#   ----------------------------------------
# ...
